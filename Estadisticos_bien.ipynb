# %% [markdown]
# Confianza de los puntos por frame del hombro derecho

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Leer CSV
csv_file = "capturas_conf_90.csv"
df = pd.read_csv(csv_file)

# Extraer datos del hombro derecho
x = df["right_shoulder_x"]
y = df["right_shoulder_y"]
conf = df["right_shoulder_conf"]

# Crear scatter plot con mapa de color
plt.figure(figsize=(8, 6))
sc = plt.scatter(x, y, c=conf, cmap="viridis", s=30)

# Barra de color para confianza
cbar = plt.colorbar(sc)
cbar.set_label("Confianza del Hombro Derecho")

plt.xlabel("X (px)")
plt.ylabel("Y (px)")
plt.title("Mapa de confianza - Hombro Derecho (X,Y vs Confianza)")

plt.gca().invert_yaxis()  # importante: en imágenes el eje Y crece hacia abajo
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carga el CSV
df = pd.read_csv("capturas_conf_90.csv")

# Si a veces hay varias personas por frame y quieres solo una,
# puedes quedarte con la detección de mayor confianza de HOMBRO DERECHO por frame:
df = (df
      .sort_values(["frame", "right_shoulder_conf"], ascending=[True, False])
      .drop_duplicates(subset=["frame"])
      .sort_values("frame"))

# Extrae series
frames = df["frame"].values
x_rs = df["right_shoulder_x"].values
y_rs = df["right_shoulder_y"].values
c_rs = df["right_shoulder_conf"].values

plt.figure(figsize=(12, 9))

# 1) Frame vs X (color por confianza)
plt.subplot(3, 1, 1)
sc1 = plt.scatter(frames, x_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Right Shoulder X (px)")
plt.title("Right Shoulder: Frame vs X (color = confianza)")
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Confianza")

# 2) Frame vs Y (color por confianza)
plt.subplot(3, 1, 2)
sc2 = plt.scatter(frames, y_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Right Shoulder Y (px)")
plt.title("Right Shoulder: Frame vs Y (color = confianza)")
cbar2 = plt.colorbar(sc2)
cbar2.set_label("Confianza")
# Nota: no invertimos eje Y aquí porque ahora el eje Y representa valor vs frame (no coordenadas en imagen)

# 3) Frame vs Confianza (línea)
plt.subplot(3, 1, 3)
plt.plot(frames, c_rs, linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Confianza")
plt.title("Right Shoulder: Confianza vs Frame")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carga el CSV
df = pd.read_csv("capturas_conf_90.csv")

# Si a veces hay varias personas por frame y quieres solo una,
# puedes quedarte con la detección de mayor confianza de HOMBRO DERECHO por frame:
df = (df
      .sort_values(["frame", "right_shoulder_conf"], ascending=[True, False])
      .drop_duplicates(subset=["frame"])
      .sort_values("frame"))

# Extrae series
frames = df["frame"].values
x_rs = df["left_shoulder_x"].values
y_rs = df["left_shoulder_y"].values
c_rs = df["left_shoulder_conf"].values

plt.figure(figsize=(12, 9))

# 1) Frame vs X (color por confianza)
plt.subplot(3, 1, 1)
sc1 = plt.scatter(frames, x_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Left Shoulder X (px)")
plt.title("Left Shoulder: Frame vs X (color = confianza)")
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Confianza")

# 2) Frame vs Y (color por confianza)
plt.subplot(3, 1, 2)
sc2 = plt.scatter(frames, y_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Leftt Shoulder Y (px)")
plt.title("Leftt Shoulder: Frame vs Y (color = confianza)")
cbar2 = plt.colorbar(sc2)
cbar2.set_label("Confianza")
# Nota: no invertimos eje Y aquí porque ahora el eje Y representa valor vs frame (no coordenadas en imagen)

# 3) Frame vs Confianza (línea)
plt.subplot(3, 1, 3)
plt.plot(frames, c_rs, linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Confianza")
plt.title("Left Shoulder: Confianza vs Frame")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carga el CSV
df = pd.read_csv("capturas_conf_90.csv")

# Si a veces hay varias personas por frame y quieres solo una,
# puedes quedarte con la detección de mayor confianza de HOMBRO DERECHO por frame:
df = (df
      .sort_values(["frame", "right_shoulder_conf"], ascending=[True, False])
      .drop_duplicates(subset=["frame"])
      .sort_values("frame"))

# Extrae series
frames = df["frame"].values
x_rs = df["right_hip_x"].values
y_rs = df["right_hip_y"].values
c_rs = df["right_hip_conf"].values

plt.figure(figsize=(12, 9))

# 1) Frame vs X (color por confianza)
plt.subplot(3, 1, 1)
sc1 = plt.scatter(frames, x_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Right Hip X (px)")
plt.title("Right Hip: Frame vs X (color = confianza)")
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Confianza")

# 2) Frame vs Y (color por confianza)
plt.subplot(3, 1, 2)
sc2 = plt.scatter(frames, y_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Right Hip Y (px)")
plt.title("Right Hip: Frame vs Y (color = confianza)")
cbar2 = plt.colorbar(sc2)
cbar2.set_label("Confianza")
# Nota: no invertimos eje Y aquí porque ahora el eje Y representa valor vs frame (no coordenadas en imagen)

# 3) Frame vs Confianza (línea)
plt.subplot(3, 1, 3)
plt.plot(frames, c_rs, linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Confianza")
plt.title("Right Hip: Confianza vs Frame")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carga el CSV
df = pd.read_csv("capturas_conf_90.csv")

# Si a veces hay varias personas por frame y quieres solo una,
# puedes quedarte con la detección de mayor confianza de HOMBRO DERECHO por frame:
df = (df
      .sort_values(["frame", "right_shoulder_conf"], ascending=[True, False])
      .drop_duplicates(subset=["frame"])
      .sort_values("frame"))

# Extrae series
frames = df["frame"].values
x_rs = df["left_hip_x"].values
y_rs = df["left_hip_y"].values
c_rs = df["left_hip_conf"].values

plt.figure(figsize=(12, 9))

# 1) Frame vs X (color por confianza)
plt.subplot(3, 1, 1)
sc1 = plt.scatter(frames, x_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Left Hip X (px)")
plt.title("Left Hip: Frame vs X (color = confianza)")
cbar1 = plt.colorbar(sc1)
cbar1.set_label("Confianza")

# 2) Frame vs Y (color por confianza)
plt.subplot(3, 1, 2)
sc2 = plt.scatter(frames, y_rs, c=c_rs, cmap="viridis", s=20)
plt.ylabel("Left Hip Y (px)")
plt.title("Left Hip: Frame vs Y (color = confianza)")
cbar2 = plt.colorbar(sc2)
cbar2.set_label("Confianza")
# Nota: no invertimos eje Y aquí porque ahora el eje Y representa valor vs frame (no coordenadas en imagen)

# 3) Frame vs Confianza (línea)
plt.subplot(3, 1, 3)
plt.plot(frames, c_rs, linewidth=1)
plt.xlabel("Frame")
plt.ylabel("Confianza")
plt.title("Left Hip: Confianza vs Frame")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Obteniedo el Rango de Frame para cada POSICIÓN y DISTANCIA
